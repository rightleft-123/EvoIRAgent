# %%
from openai import OpenAI
import requests
import json

# %%
# url = "http://172.25.74.142:3001/proxy/openrouter/v1/chat/completions"
# headers = {
#     "Authorization": "Bearer sk-QFq0XpPzUCluu3PMnSStQPdrEpD2fW80NoLHakTc5zjFaVdK",
#     "Content-Type": "application/json"
# }
# data = {
#     "model": "mistralai/mistral-small-3.1-24b-instruct:free",
#     "messages": [{"role": "user", "content": "who are you?"}]
# }

# response = requests.post(url, headers=headers, json=data)
# print(response.json())

# %%
import sys
sys.path.append('D:\\zkl\\研一\\实验\\Agent\\AgenticIR')
from llm.gemini import Gemini
from pathlib import Path
import json

# %%
# depictqa = DepictQA()
# response = depictqa.query(
#     img_path_lst=[Path("/data/zkl/AgenticIR/dataset/haze/RESIDE-6k/hazy/42.jpg")],
#     task="eval_degradation",
# )[1]
# print(response)

# %%
# for name, desc in response:
#     print(f"{name}")
#     print(f"{desc}")
#     print("-----")

# %%
# print(response)
# import json

# formatted = [{name: desc} for name, desc in response]
# print(json.dumps(formatted, indent=4, ensure_ascii=False))

# %%
gemini = Gemini()
response = gemini.query(
    prompt="Who are you?"
)[1]
print(response)
